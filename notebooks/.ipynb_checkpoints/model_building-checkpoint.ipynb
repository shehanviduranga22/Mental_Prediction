# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip install panda
# Out:
# Collecting panda
#   Downloading panda-0.3.1.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: setuptools in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from panda) (80.9.0)
# Requirement already satisfied: requests in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from panda) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from requests->panda) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from requests->panda) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from requests->panda) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from requests->panda) (2025.11.12)
# Building wheels for collected packages: panda
#   Building wheel for panda (pyproject.toml): started
#   Building wheel for panda (pyproject.toml): finished with status 'done'
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7285 sha256=a906ec9ce3649f92782cdbf154f1bba945198c198dda762cbf1e0b8ae46543e6
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\b3\62\ac\41e27178e8597be2da908681ca1e75e66255a488040cca1638
# Successfully built panda
# Installing collected packages: panda
# Successfully installed panda-0.3.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data = pd.read_csv('../artifacts/Combined Data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety

# %% [markdown]
# ### Data Preprocessing

# %%
data.shape
# Out:
# (53043, 3)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      0
# statement     362
# status          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Text Preprocessing

# %%
import re
import string

# %%
data["statement"].head(5)
# Out:
# 0                                           oh my gosh
# 1    trouble sleeping, confused mind, restless hear...
# 2    All wrong, back off dear, forward doubt. Stay ...
# 3    I've shifted my focus to something else but I'...
# 4    I'm restless and restless, it's been a month n...
# Name: statement, dtype: object

# %% [markdown]
# ##### Convert uppercase to lowercase

# %%
data["statement"] = data["statement"].astype(str).apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
data["statement"].head(5)
# Out:
# 0                                           oh my gosh
# 1    trouble sleeping, confused mind, restless hear...
# 2    all wrong, back off dear, forward doubt. stay ...
# 3    i've shifted my focus to something else but i'...
# 4    i'm restless and restless, it's been a month n...
# Name: statement, dtype: object

# %% [markdown]
# ##### Remove Links

# %%
data["statement"] = data["statement"].astype(str).apply(
    lambda x: " ".join(re.sub(r'https?://\S+|www\.\S+', '', word)for word in x.split()))

# %% [markdown]
# ##### Remove punctuation

# %%
data["statement"] = data["statement"].astype(str).apply(
    lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# %%
data["statement"].head(5)
# Out:
# 0                                           oh my gosh
# 1    trouble sleeping confused mind restless heart ...
# 2    all wrong back off dear forward doubt stay in ...
# 3    ive shifted my focus to something else but im ...
# 4    im restless and restless its been a month now ...
# Name: statement, dtype: object

# %% [markdown]
# ##### Remove numbers

# %%
data["statement"] = data["statement"].astype(str).apply(
    lambda x: re.sub(r'\d+', '', x))

# %% [markdown]
# ##### Remove Stopping words

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.11.3-cp314-cp314-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 544.4 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 544.4 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 544.4 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 544.4 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 544.4 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 544.4 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.5 MB 307.8 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.5 MB 307.8 kB/s eta 0:00:03
#    --------------------------- ------------ 1.0/1.5 MB 368.8 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.3/1.5 MB 431.8 kB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 479.4 kB/s  0:00:03
# Downloading regex-2025.11.3-cp314-cp314-win_amd64.whl (280 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk
#
#    ---------------------------------------- 0/5 [tqdm]
#    ---------------------------------------- 0/5 [tqdm]
#    -------- ------------------------------- 1/5 [regex]
#    -------- ------------------------------- 1/5 [regex]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ---------------- ----------------------- 2/5 [joblib]
#    ------------------------ --------------- 3/5 [click]
#    ------------------------ --------------- 3/5 [click]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    -------------------------------- ------- 4/5 [nltk]
#    ---------------------------------------- 5/5 [nltk]
#
# Successfully installed click-8.3.1 joblib-1.5.2 nltk-3.9.2 regex-2025.11.3 tqdm-4.67.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

with open('../static/model/nltk_data/corpora/stopwords/english', 'r') as file:
    sw = file.read().splitlines()

# %%
data["statement"] = data["statement"].astype(str).apply(
    lambda x: " ".join(word for word in x.split() if word.lower() not in sw))

# %%
data.head(5)
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                            oh gosh  Anxiety
# 1           1  trouble sleeping confused mind restless heart ...  Anxiety
# 2           2  wrong back dear forward doubt stay restless re...  Anxiety
# 3           3  ive shifted focus something else im still worried  Anxiety
# 4           4                im restless restless month boy mean  Anxiety

# %% [markdown]
# ##### Stemming

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
data["statement"] = data["statement"].astype(str).apply(
    lambda x: " ".join(ps.stem(x) for x in x.split()))

# %%
data
# Out:
#        Unnamed: 0                                          statement   status
# 0               0                                            oh gosh  Anxiety
# 1               1       troubl sleep confus mind restless heart tune  Anxiety
# 2               2  wrong back dear forward doubt stay restless re...  Anxiety
# 3               3           ive shift focu someth els im still worri  Anxiety
# 4               4                im restless restless month boy mean  Anxiety
# ...           ...                                                ...      ...
# 53038       53038  nobodi take serious i’v dealt depressionanxiet...  Anxiety
# 53039       53039  selfish dont feel good like dont belong world ...  Anxiety
# 53040       53040   way sleep better cant sleep night med didnt help  Anxiety
# 53041       53041  public speak tip hi give present work next wee...  Anxiety
# 53042       53042  realli bad door anxieti scare didnt lock door ...  Anxiety
#
# [53043 rows x 3 columns]

# %% [markdown]
# #### Building Vacabulary

# %%
from collections import Counter
vocab = Counter()

# %%
for sentence in data["statement"]:
    vocab.update(sentence.split())

# %%
vocab
# Out:
# Counter({'feel': 45566,
#          'like': 39643,
#          'want': 33648,
#          'get': 29366,
#          'go': 26295,
#          'know': 25546,
#          'life': 22314,
#          'time': 21284,
#          'even': 18950,
#          'think': 17575,
#          'peopl': 16855,
#          'would': 16798,
#          'year': 16564,
#          'day': 16479,
#          'realli': 16370,
#          'thing': 16281,
#          'one': 15528,
#          'tri': 15435,
#          'make': 15407,
#          'cannot': 15393,
#          'depress': 14412,
#          'im': 13829,
#          'help': 13542,
#          'work': 13456,
#          'friend': 13191,
#          'take': 11911,
#          'much': 11844,
#          'never': 11765,
#          'live': 11616,
#          'start': 10477,
#          'fuck': 10425,
#          'could': 9791,
#          'need': 9763,
#          'thought': 9678,
#          'back': 9437,
#          'anymor': 9409,
#          'anxieti': 9279,
#          'talk': 9264,
#          'see': 9106,
#          'way': 8949,
#          'anyth': 8947,
#          'still': 8932,
#          'someth': 8682,
#          'love': 8657,
#          'say': 8524,
#          'good': 8440,
#          'got': 8425,
#          'alway': 8413,
#          'end': 8402,
#          'anyon': 8303,
#          'everyth': 8262,
#          'die': 8053,
#          'better': 7851,
#          'i’m': 7683,
#          'everi': 7666,
#          'hate': 7653,
#          'noth': 7356,
#          'month': 7298,
#          'someon': 7278,
#          'also': 7198,
#          'bad': 7108,
#          'famili': 7090,
#          'sinc': 6982,
#          'last': 6947,
#          'person': 6905,
#          'job': 6878,
#          'look': 6798,
#          'suicid': 6792,
#          'right': 6764,
#          'week': 6733,
#          'keep': 6711,
#          'dont': 6677,
#          'tell': 6646,
#          'care': 6641,
#          'come': 6280,
#          'kill': 6101,
#          'stop': 6064,
#          'pain': 6042,
#          'lot': 5894,
#          'ever': 5845,
#          'happi': 5782,
#          'find': 5667,
#          'use': 5659,
#          'everyon': 5647,
#          'happen': 5614,
#          'tire': 5552,
#          'long': 5532,
#          'point': 5488,
#          'sleep': 5305,
#          'hard': 5227,
#          'around': 5222,
#          'els': 5146,
#          'give': 5079,
#          'school': 5047,
#          'first': 5039,
#          'mental': 5038,
#          'seem': 5029,
#          'hope': 5001,
#          'well': 4986,
#          'away': 4913,
#          'felt': 4904,
#          'ask': 4892,
#          'ive': 4884,
#          'told': 4861,
#          'shit': 4786,
#          'alon': 4724,
#          'made': 4700,
#          'wish': 4666,
#          'hurt': 4582,
#          'parent': 4581,
#          'said': 4519,
#          'ago': 4468,
#          'stress': 4461,
#          'mayb': 4333,
#          'wors': 4223,
#          'actual': 4216,
#          'enough': 4185,
#          'reason': 4178,
#          'went': 4122,
#          'past': 4049,
#          'mani': 4022,
#          'ill': 4008,
#          'new': 3984,
#          'scare': 3977,
#          'night': 3886,
#          'problem': 3884,
#          'today': 3869,
#          'world': 3863,
#          'sure': 3860,
#          'home': 3860,
#          'wa': 3848,
#          'move': 3837,
#          'cri': 3833,
#          'let': 3824,
#          'call': 3809,
#          'done': 3779,
#          'abl': 3771,
#          'leav': 3756,
#          'put': 3751,
#          'sometim': 3732,
#          'health': 3732,
#          'littl': 3664,
#          'sad': 3645,
#          'though': 3634,
#          'without': 3603,
#          'worri': 3595,
#          'best': 3577,
#          'relationship': 3541,
#          'chang': 3534,
#          'mom': 3507,
#          'left': 3473,
#          'hour': 3445,
#          'two': 3440,
#          'mind': 3427,
#          'head': 3392,
#          'post': 3385,
#          'struggl': 3359,
#          'understand': 3345,
#          'cant': 3338,
#          'kind': 3325,
#          'normal': 3268,
#          'lost': 3257,
#          'old': 3253,
#          'don’t': 3245,
#          'read': 3230,
#          'place': 3197,
#          'pleas': 3195,
#          'thank': 3171,
#          'anoth': 3171,
#          'almost': 3156,
#          'it’': 3147,
#          'medic': 3142,
#          'i’v': 3094,
#          'alreadi': 3053,
#          'wrong': 3052,
#          'issu': 3019,
#          'doctor': 3014,
#          'emot': 3009,
#          'stay': 2979,
#          'deal': 2968,
#          'mean': 2954,
#          'eat': 2952,
#          'final': 2909,
#          'complet': 2883,
#          'differ': 2873,
#          'experi': 2864,
#          'pretti': 2860,
#          'probabl': 2857,
#          'might': 2831,
#          'self': 2827,
#          'money': 2798,
#          'social': 2781,
#          'guy': 2774,
#          'therapi': 2766,
#          'recent': 2738,
#          'heart': 2703,
#          'becom': 2642,
#          'sorri': 2638,
#          'suffer': 2636,
#          'brain': 2618,
#          'turn': 2571,
#          'bodi': 2566,
#          'next': 2565,
#          'hous': 2559,
#          'symptom': 2550,
#          'other': 2546,
#          'med': 2546,
#          'part': 2528,
#          'matter': 2492,
#          'caus': 2473,
#          'guess': 2461,
#          'high': 2437,
#          'plan': 2387,
#          'yet': 2379,
#          'bit': 2364,
#          'wake': 2360,
#          'believ': 2352,
#          'fear': 2333,
#          'sick': 2323,
#          'close': 2310,
#          'us': 2300,
#          'bed': 2298,
#          'advic': 2298,
#          'rememb': 2286,
#          'support': 2284,
#          'therapist': 2282,
#          'dad': 2281,
#          'liter': 2269,
#          'whole': 2234,
#          'exist': 2222,
#          'lose': 2220,
#          'late': 2218,
#          'least': 2215,
#          'gone': 2177,
#          'found': 2175,
#          'death': 2170,
#          'kid': 2168,
#          'real': 2167,
#          'bipolar': 2158,
#          'took': 2141,
#          'attack': 2141,
#          'constantli': 2135,
#          'wait': 2132,
#          'stuff': 2130,
#          'break': 2123,
#          'quit': 2109,
#          'colleg': 2103,
#          'realiz': 2099,
#          'abus': 2097,
#          'miss': 2089,
#          'wonder': 2086,
#          'idea': 2086,
#          'either': 2084,
#          'diagnos': 2084,
#          'enjoy': 2069,
#          'girl': 2053,
#          'situat': 2051,
#          'great': 2045,
#          'due': 2043,
#          'sever': 2040,
#          'physic': 2019,
#          'anxiou': 1973,
#          'anyway': 1972,
#          'moment': 1969,
#          'extrem': 1948,
#          'play': 1936,
#          'side': 1931,
#          'came': 1923,
#          'write': 1907,
#          'current': 1898,
#          'fail': 1891,
#          'watch': 1890,
#          'mother': 1883,
#          'etc': 1880,
#          'coupl': 1880,
#          'futur': 1876,
#          'episod': 1867,
#          'decid': 1862,
#          'panic': 1861,
#          'may': 1850,
#          'stupid': 1843,
#          'soon': 1836,
#          'everyday': 1825,
#          'okay': 1819,
#          'honestli': 1812,
#          'morn': 1810,
#          'possibl': 1804,
#          'basic': 1795,
#          'face': 1783,
#          'fine': 1762,
#          'usual': 1759,
#          'hear': 1758,
#          'cut': 1750,
#          'fight': 1741,
#          'interest': 1735,
#          'show': 1732,
#          'idk': 1731,
#          'dream': 1716,
#          'afraid': 1714,
#          'room': 1710,
#          'drink': 1695,
#          'control': 1686,
#          'manag': 1680,
#          'fall': 1674,
#          'notic': 1673,
#          'question': 1669,
#          'disord': 1666,
#          'can’t': 1665,
#          'togeth': 1663,
#          'walk': 1659,
#          'pay': 1656,
#          'didnt': 1650,
#          'nobodi': 1646,
#          'id': 1643,
#          'hit': 1638,
#          'aliv': 1637,
#          'later': 1634,
#          'worst': 1633,
#          'hospit': 1631,
#          'longer': 1629,
#          'weird': 1626,
#          'worth': 1615,
#          'pass': 1604,
#          'hell': 1590,
#          'far': 1579,
#          'motiv': 1577,
#          'studi': 1577,
#          'deserv': 1574,
#          'state': 1558,
#          'sit': 1558,
#          'date': 1556,
#          'fact': 1555,
#          'attempt': 1554,
#          'second': 1551,
#          'ha': 1544,
#          'dead': 1541,
#          'often': 1523,
#          'open': 1517,
#          'suppos': 1511,
#          'less': 1509,
#          'spend': 1507,
#          'car': 1506,
#          'suck': 1501,
#          'game': 1498,
#          'god': 1493,
#          'run': 1493,
#          'singl': 1485,
#          'bare': 1485,
#          'continu': 1478,
#          'hold': 1469,
#          'word': 1467,
#          'age': 1466,
#          'learn': 1462,
#          'big': 1458,
#          'listen': 1444,
#          'absolut': 1441,
#          'stuck': 1437,
#          'bring': 1434,
#          'horribl': 1432,
#          'drive': 1429,
#          'hand': 1425,
#          'eye': 1423,
#          'lie': 1419,
#          'stori': 1417,
#          'sound': 1411,
#          'full': 1401,
#          'share': 1397,
#          'minut': 1394,
#          'man': 1384,
#          'nice': 1381,
#          'energi': 1377,
#          'fun': 1370,
#          'amp': 1370,
#          'instead': 1369,
#          'test': 1366,
#          'human': 1354,
#          'entir': 1352,
#          'howev': 1350,
#          'low': 1348,
#          'class': 1345,
#          'sens': 1345,
#          'mg': 1342,
#          'small': 1341,
#          'lone': 1341,
#          'brother': 1340,
#          'food': 1339,
#          'wast': 1338,
#          'boyfriend': 1333,
#          'knew': 1331,
#          'posit': 1330,
#          'experienc': 1328,
#          'act': 1325,
#          'type': 1324,
#          'insid': 1318,
#          'breath': 1317,
#          'hang': 1316,
#          'rest': 1302,
#          'check': 1301,
#          'girlfriend': 1300,
#          'comfort': 1297,
#          'relat': 1297,
#          'effect': 1294,
#          'reach': 1291,
#          'push': 1289,
#          'gener': 1285,
#          'mood': 1283,
#          'empti': 1277,
#          'truli': 1276,
#          'gotten': 1269,
#          'phone': 1267,
#          'expect': 1267,
#          'apart': 1267,
#          'cours': 1265,
#          'drug': 1258,
#          'exhaust': 1252,
#          'accept': 1246,
#          'terribl': 1246,
#          'cope': 1242,
#          'meet': 1241,
#          'father': 1232,
#          'especi': 1231,
#          'ruin': 1227,
#          'half': 1219,
#          'constant': 1219,
#          'sister': 1208,
#          'angri': 1195,
#          'chest': 1193,
#          'short': 1183,
#          'forc': 1183,
#          'blood': 1179,
#          'whatev': 1176,
#          'mess': 1175,
#          'broke': 1173,
#          'outsid': 1171,
#          'onlin': 1168,
#          'gave': 1166,
#          'that': 1164,
#          'handl': 1164,
#          'ok': 1161,
#          'treat': 1159,
#          'goe': 1156,
#          'cancer': 1155,
#          'consid': 1151,
#          'child': 1134,
#          'group': 1126,
#          'tomorrow': 1125,
#          'partner': 1123,
#          'doesnt': 1122,
#          'crazi': 1120,
#          'psychiatrist': 1119,
#          'hi': 1113,
#          'fix': 1110,
#          'sort': 1110,
#          'weight': 1105,
#          'explain': 1105,
#          'trigger': 1088,
#          'save': 1088,
#          'avoid': 1087,
#          'saw': 1086,
#          'trust': 1084,
#          'deep': 1066,
#          'spent': 1064,
#          'appreci': 1060,
#          'he': 1057,
#          'seen': 1055,
#          'dog': 1044,
#          'pill': 1044,
#          'figur': 1044,
#          'free': 1043,
#          'vent': 1039,
#          'rather': 1033,
#          'convinc': 1033,
#          'univers': 1030,
#          'answer': 1027,
#          'speak': 1022,
#          'taken': 1018,
#          'forward': 1016,
#          'super': 1015,
#          'ye': 1007,
#          'follow': 1006,
#          'stand': 1005,
#          'peac': 1004,
#          'neg': 1003,
#          'respons': 1002,
#          'numb': 1001,
#          'whenev': 1000,
#          'yesterday': 996,
#          'countri': 993,
#          'three': 990,
#          'eventu': 984,
#          'text': 982,
#          'commit': 982,
#          'harm': 982,
#          'option': 979,
#          'miser': 975,
#          'kept': 972,
#          'video': 969,
#          'major': 962,
#          'burden': 961,
#          'ignor': 961,
#          'difficult': 961,
#          'chanc': 961,
#          'affect': 953,
#          'oh': 951,
#          'clean': 949,
#          'readi': 949,
#          'failur': 949,
#          'grow': 947,
#          'dark': 945,
#          'begin': 945,
#          'manic': 945,
#          'met': 941,
#          'behind': 940,
#          'strong': 936,
#          'freak': 934,
#          'fast': 931,
#          'grade': 931,
#          'memori': 930,
#          'serious': 928,
#          'easi': 925,
#          'sex': 924,
#          'alcohol': 924,
#          'drop': 923,
#          'set': 919,
#          'appoint': 918,
#          'given': 917,
#          'bother': 917,
#          'result': 916,
#          'terrifi': 916,
#          'shitti': 914,
#          'trauma': 913,
#          'smoke': 913,
#          'buy': 911,
#          'amount': 911,
#          'top': 907,
#          'overwhelm': 906,
#          'commun': 904,
#          'imagin': 901,
#          'convers': 899,
#          'true': 897,
#          'young': 897,
#          'genuin': 896,
#          'finish': 889,
#          'forget': 887,
#          'forev': 887,
#          'case': 882,
#          'hey': 882,
#          'aw': 879,
#          'damn': 877,
#          'activ': 876,
#          'healthi': 876,
#          'broken': 874,
#          'music': 873,
#          'afford': 871,
#          'step': 866,
#          'laugh': 865,
#          'busi': 863,
#          'earli': 861,
#          'realiti': 860,
#          'allow': 859,
#          'success': 858,
#          'calm': 855,
#          'mistak': 855,
#          'th': 855,
#          'graduat': 853,
#          'born': 853,
#          'connect': 851,
#          'daili': 851,
#          'upset': 846,
#          'name': 844,
#          'ex': 843,
#          'period': 841,
#          'mention': 837,
#          'stomach': 836,
#          'pressur': 834,
#          'function': 834,
#          'toward': 833,
#          'becam': 830,
#          'cold': 830,
#          'surviv': 829,
#          'blame': 828,
#          'import': 827,
#          'similar': 827,
#          'tonight': 825,
#          'lack': 824,
#          'total': 823,
#          'useless': 821,
#          'focu': 820,
#          'mostli': 820,
#          'despit': 819,
#          'pick': 815,
#          'improv': 814,
#          'level': 813,
#          'lol': 811,
#          'piec': 807,
#          'except': 806,
#          'bore': 804,
#          'worthless': 804,
#          'attent': 802,
#          'treatment': 797,
#          'slowli': 796,
#          'covid': 793,
#          'cycl': 787,
#          'bc': 787,
#          'lay': 786,
#          'selfish': 786,
#          'along': 784,
#          'messag': 779,
#          'confus': 778,
#          'fault': 774,
#          'wife': 772,
#          'heard': 772,
#          'note': 772,
#          'hopeless': 771,
#          'disappoint': 769,
#          'confid': 767,
#          'contact': 767,
#          'didn’t': 767,
#          'mine': 766,
#          'front': 765,
#          'antidepress': 765,
#          'joke': 763,
#          'order': 763,
#          'isol': 759,
#          'develop': 758,
#          'multipl': 750,
#          'decis': 749,
#          'childhood': 749,
#          'light': 748,
#          'frustrat': 746,
#          'addict': 745,
#          'definit': 743,
#          'husband': 743,
#          'annoy': 743,
#          'fake': 743,
#          'none': 742,
#          'seriou': 741,
#          'must': 740,
#          'escap': 737,
#          'somehow': 736,
#          'huge': 735,
#          'career': 732,
#          'seek': 731,
#          'sexual': 730,
#          'throw': 729,
#          'whether': 727,
#          'reddit': 726,
#          'water': 722,
#          'term': 722,
#          'excit': 721,
#          'yeah': 721,
#          'weak': 717,
#          'lead': 717,
#          'havent': 716,
#          'suddenli': 715,
#          'harder': 707,
#          'woke': 705,
#          'ugli': 703,
#          'f': 702,
#          'suggest': 700,
#          'purpos': 700,
#          'adult': 699,
#          'woman': 699,
#          'send': 699,
#          'sign': 698,
#          'birthday': 698,
#          'bulli': 698,
#          'goal': 696,
#          'student': 693,
#          'troubl': 687,
#          'hello': 687,
#          'kick': 687,
#          'book': 686,
#          'jump': 685,
#          'anybodi': 685,
#          'hobbi': 684,
#          'distract': 682,
#          'pull': 681,
#          'effort': 678,
#          'summer': 678,
#          'regret': 677,
#          'beat': 675,
#          'visit': 671,
#          'concern': 671,
#          'there': 669,
#          'mad': 668,
#          'nervou': 662,
#          'guilti': 662,
#          'immedi': 662,
#          'anger': 656,
#          'process': 656,
#          'middl': 656,
#          'tip': 655,
#          'clear': 654,
#          'remind': 652,
#          'voic': 651,
#          'build': 650,
#          'lazi': 649,
#          'hair': 649,
#          'awar': 648,
#          'touch': 647,
#          'beauti': 646,
#          'older': 645,
#          'comment': 645,
#          'safe': 644,
#          'simpli': 644,
#          'exercis': 641,
#          'wasnt': 639,
#          'random': 639,
#          'offer': 639,
#          'natur': 638,
#          'easier': 638,
#          'marri': 637,
#          'fill': 636,
#          'although': 636,
#          'intens': 636,
#          'isnt': 635,
#          'account': 635,
#          'diagnosi': 635,
#          'form': 634,
#          'interact': 633,
#          'choic': 630,
#          'includ': 630,
#          'cat': 629,
#          'arm': 627,
#          'desper': 627,
#          'smile': 626,
#          'somewher': 624,
#          'friendship': 618,
#          'scream': 618,
#          'degre': 618,
#          'asleep': 613,
#          'embarrass': 613,
#          'headach': 612,
#          'within': 610,
#          'googl': 609,
#          'fit': 609,
#          'destroy': 609,
#          'pathet': 608,
#          'space': 607,
#          'imposs': 607,
#          'hide': 607,
#          'societi': 606,
#          'adhd': 606,
#          'toxic': 604,
#          'na': 603,
#          'rant': 603,
#          'avpd': 602,
#          'badli': 599,
#          'sent': 598,
#          'gain': 597,
#          'tear': 597,
#          'financi': 595,
#          'amaz': 594,
#          'straight': 594,
#          'realis': 594,
#          'weekend': 592,
#          'perfect': 591,
#          'obvious': 591,
#          'burn': 591,
#          'prescrib': 590,
#          'certain': 589,
#          'pretend': 589,
#          'incred': 589,
#          'shower': 588,
#          'event': 585,
#          'citi': 584,
#          'spiral': 584,
#          'disappear': 583,
#          'unabl': 581,
#          'joy': 579,
#          'honest': 578,
#          'creat': 576,
#          'shake': 574,
#          'progress': 573,
#          'exactli': 571,
#          'mum': 570,
#          'psych': 570,
#          'funni': 567,
#          'reject': 567,
#          'meant': 567,
#          'shut': 566,
#          'dose': 564,
#          'exampl': 564,
#          'drunk': 560,
#          'condit': 559,
#          'express': 559,
#          'mania': 559,
#          'wont': 558,
#          'area': 558,
#          'your': 556,
#          'insur': 555,
#          'desir': 553,
#          'disgust': 552,
#          'list': 551,
#          'line': 550,
#          'skin': 548,
#          'doubt': 547,
#          'weed': 547,
#          'stabl': 547,
#          'diseas': 546,
#          'loss': 544,
#          'women': 543,
#          'system': 542,
#          'skill': 542,
#          'till': 542,
#          'increas': 541,
#          'movi': 541,
#          'profession': 541,
#          'return': 540,
#          'choos': 538,
#          'near': 536,
#          'ptsd': 535,
#          'proud': 534,
#          'gun': 533,
#          'guilt': 533,
#          'train': 532,
#          'trap': 532,
#          'appli': 530,
#          'hole': 530,
#          'research': 529,
#          'nearli': 529,
#          'x': 526,
#          'admit': 526,
#          'daughter': 526,
#          'damag': 525,
#          'internet': 524,
#          'poor': 523,
#          'member': 523,
#          'son': 522,
#          'describ': 522,
#          'u': 521,
#          'parti': 521,
#          'respond': 521,
#          'exam': 520,
#          'leg': 518,
#          'easili': 517,
#          'neck': 517,
#          'dumb': 516,
#          'younger': 516,
#          'door': 513,
#          'specif': 513,
#          'refus': 513,
#          'trip': 512,
#          'relax': 510,
#          'achiev': 510,
#          'insan': 509,
#          'male': 508,
#          'twice': 508,
#          'appar': 507,
#          'pictur': 507,
#          'bill': 506,
#          'anywher': 506,
#          'throat': 503,
#          'couldnt': 502,
#          'medicin': 501,
#          'throughout': 501,
#          'obsess': 501,
#          'teacher': 499,
#          'rare': 498,
#          'simpl': 496,
#          'fire': 495,
#          'loneli': 495,
#          'babi': 494,
#          'quickli': 493,
#          'that’': 492,
#          'compani': 490,
#          'what': 488,
#          'nightmar': 488,
#          'present': 487,
#          'attract': 486,
#          'doesn’t': 486,
#          'known': 485,
#          'brought': 485,
#          'receiv': 483,
#          'switch': 482,
#          'uncomfort': 481,
#          'chat': 480,
#          'opportun': 480,
#          'nowher': 480,
#          'yell': 480,
#          'inform': 479,
#          'practic': 479,
#          'ampxb': 479,
#          'besid': 475,
#          'kinda': 472,
#          'fell': 472,
#          'began': 472,
#          'shame': 470,
#          'gonna': 470,
#          'promis': 469,
#          'i’ll': 469,
#          'number': 468,
#          'product': 467,
#          'bullshit': 464,
#          'battl': 464,
#          'slow': 462,
#          'repli': 460,
#          'sub': 460,
#          'wear': 459,
#          'everytim': 459,
#          'chronic': 459,
#          'potenti': 458,
#          'schedul': 457,
#          'action': 457,
#          'truth': 457,
#          'pandem': 455,
#          'loser': 455,
#          'add': 455,
#          'pointless': 455,
#          'provid': 454,
#          'block': 453,
#          'travel': 452,
#          'offic': 452,
#          'disabl': 452,
#          'fulli': 451,
#          'task': 450,
#          'ass': 450,
#          'behavior': 450,
#          'wall': 448,
#          'restless': 447,
#          'view': 447,
#          'homeless': 446,
#          'common': 445,
#          'bunch': 444,
#          'children': 442,
#          'passion': 441,
#          'rais': 440,
#          'urg': 440,
#          'apolog': 439,
#          'mix': 438,
#          'scari': 438,
#          'breakdown': 436,
#          'drain': 434,
#          'hug': 433,
#          'somebodi': 433,
#          'boy': 432,
#          'heavi': 432,
#          'heal': 432,
#          'rent': 432,
#          'histori': 432,
#          'ocd': 432,
#          'compar': 431,
#          'session': 431,
#          'appear': 430,
#          'media': 430,
#          'titl': 430,
#          'rate': 430,
#          'black': 428,
#          'program': 428,
#          'cool': 427,
#          'unless': 427,
#          'traumat': 426,
#          'mei': 426,
#          'valu': 425,
#          'race': 424,
#          'repeat': 424,
#          'detail': 423,
#          'tho': 423,
#          'unfortun': 423,
#          'sibl': 423,
#          'solut': 422,
#          'soul': 420,
#          'app': 419,
#          'everybodi': 419,
#          'cloth': 418,
#          'excus': 418,
#          'interview': 418,
#          'search': 417,
#          'project': 416,
#          'main': 416,
#          'abil': 416,
#          'cheat': 415,
#          'wrote': 415,
#          'crush': 414,
#          'lucki': 412,
#          'carri': 412,
#          'four': 406,
#          'judg': 405,
#          'goodby': 404,
#          'cover': 403,
#          'relief': 403,
#          'dread': 402,
#          'bought': 401,
#          'smart': 400,
#          'bf': 400,
#          'overdos': 400,
#          'haven’t': 400,
#          'earlier': 399,
#          'invit': 399,
#          'she': 399,
#          'lower': 398,
#          'properli': 398,
#          'anim': 397,
#          'lithium': 396,
#          'stranger': 395,
#          'habit': 394,
#          'earth': 394,
#          'quiet': 394,
#          'men': 394,
#          ...})

# %%
len(vocab)
# Out:
# 61185

# %%
tokens = [key for key in vocab if vocab[key]>10]

# %%
len(tokens)
# Out:
# 7248

# %%
def save_vocabulary(lines,filename):
    data = '\n'.join(lines)
    file = open(filename,'w',encoding="utf-8")
    file.write(data)
    file.close()

save_vocabulary(tokens, '../static/model/vocablary.txt')

# %% [markdown]
# #### Divide Dataset

# %%
data
# Out:
#        Unnamed: 0                                          statement   status
# 0               0                                            oh gosh  Anxiety
# 1               1       troubl sleep confus mind restless heart tune  Anxiety
# 2               2  wrong back dear forward doubt stay restless re...  Anxiety
# 3               3           ive shift focu someth els im still worri  Anxiety
# 4               4                im restless restless month boy mean  Anxiety
# ...           ...                                                ...      ...
# 53038       53038  nobodi take serious i’v dealt depressionanxiet...  Anxiety
# 53039       53039  selfish dont feel good like dont belong world ...  Anxiety
# 53040       53040   way sleep better cant sleep night med didnt help  Anxiety
# 53041       53041  public speak tip hi give present work next wee...  Anxiety
# 53042       53042  realli bad door anxieti scare didnt lock door ...  Anxiety
#
# [53043 rows x 3 columns]

# %%
X = data["statement"]
Y = data["status"]

# %%
# !pip install sklearn-model
# Out:
# Collecting sklearn-model
#   Downloading sklearn_model-0.0.6-py3-none-any.whl.metadata (2.7 kB)
# Collecting scikit-learn>=0.22 (from sklearn-model)
#   Downloading scikit_learn-1.7.2-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: pandas in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from sklearn-model) (2.3.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from scikit-learn>=0.22->sklearn-model) (2.3.5)
# Collecting scipy>=1.8.0 (from scikit-learn>=0.22->sklearn-model)
#   Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from scikit-learn>=0.22->sklearn-model) (1.5.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.22->sklearn-model)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from pandas->sklearn-model) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from pandas->sklearn-model) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from pandas->sklearn-model) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->sklearn-model) (1.17.0)
# Downloading sklearn_model-0.0.6-py3-none-any.whl (6.6 kB)
# Downloading scikit_learn-1.7.2-cp314-cp314-win_amd64.whl (8.8 MB)
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.8 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.8 MB 2.9 MB/s eta 0:00:03
#    --------- ------------------------------ 2.1/8.8 MB 3.7 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.8 MB 4.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.9/8.8 MB 4.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.2/8.8 MB 4.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.0/8.8 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.8 MB 4.6 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.8 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 4.6 MB/s  0:00:01
# Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl (39.4 MB)
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.4 MB 1.5 MB/s eta 0:00:26
#    - -------------------------------------- 1.0/39.4 MB 2.0 MB/s eta 0:00:19
#    - -------------------------------------- 1.3/39.4 MB 1.8 MB/s eta 0:00:22
#    - -------------------------------------- 1.6/39.4 MB 1.7 MB/s eta 0:00:22
#    - -------------------------------------- 1.8/39.4 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.1/39.4 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.4/39.4 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.4/39.4 MB 1.5 MB/s eta 0:00:25
#    -- ------------------------------------- 2.6/39.4 MB 1.4 MB/s eta 0:00:27
#    -- ------------------------------------- 2.9/39.4 MB 1.3 MB/s eta 0:00:28
#    --- ------------------------------------ 3.1/39.4 MB 1.3 MB/s eta 0:00:28
#    --- ------------------------------------ 3.4/39.4 MB 1.3 MB/s eta 0:00:27
#    --- ------------------------------------ 3.7/39.4 MB 1.3 MB/s eta 0:00:28
#    --- ------------------------------------ 3.9/39.4 MB 1.3 MB/s eta 0:00:28
#    ---- ----------------------------------- 4.5/39.4 MB 1.3 MB/s eta 0:00:26
#    ---- ----------------------------------- 4.7/39.4 MB 1.4 MB/s eta 0:00:26
#    ----- ---------------------------------- 5.2/39.4 MB 1.4 MB/s eta 0:00:24
#    ----- ---------------------------------- 5.5/39.4 MB 1.4 MB/s eta 0:00:24
#    ----- ---------------------------------- 5.8/39.4 MB 1.4 MB/s eta 0:00:24
#    ------ --------------------------------- 6.3/39.4 MB 1.5 MB/s eta 0:00:23
#    ------- -------------------------------- 7.1/39.4 MB 1.6 MB/s eta 0:00:21
#    ------- -------------------------------- 7.9/39.4 MB 1.7 MB/s eta 0:00:19
#    --------- ------------------------------ 8.9/39.4 MB 1.8 MB/s eta 0:00:17
#    ---------- ----------------------------- 10.2/39.4 MB 2.0 MB/s eta 0:00:15
#    ----------- ---------------------------- 11.3/39.4 MB 2.1 MB/s eta 0:00:14
#    ------------ --------------------------- 12.3/39.4 MB 2.2 MB/s eta 0:00:13
#    ------------- -------------------------- 13.4/39.4 MB 2.3 MB/s eta 0:00:12
#    -------------- ------------------------- 14.4/39.4 MB 2.4 MB/s eta 0:00:11
#    --------------- ------------------------ 15.5/39.4 MB 2.5 MB/s eta 0:00:10
#    ---------------- ----------------------- 16.5/39.4 MB 2.6 MB/s eta 0:00:09
#    ----------------- ---------------------- 17.6/39.4 MB 2.7 MB/s eta 0:00:09
#    ------------------- -------------------- 18.9/39.4 MB 2.8 MB/s eta 0:00:08
#    -------------------- ------------------- 19.9/39.4 MB 2.9 MB/s eta 0:00:07
#    --------------------- ------------------ 21.0/39.4 MB 2.9 MB/s eta 0:00:07
#    ---------------------- ----------------- 22.0/39.4 MB 3.0 MB/s eta 0:00:06
#    ----------------------- ---------------- 23.1/39.4 MB 3.1 MB/s eta 0:00:06
#    ------------------------ --------------- 24.1/39.4 MB 3.1 MB/s eta 0:00:05
#    ------------------------- -------------- 25.4/39.4 MB 3.2 MB/s eta 0:00:05
#    -------------------------- ------------- 26.5/39.4 MB 3.2 MB/s eta 0:00:04
#    --------------------------- ------------ 27.5/39.4 MB 3.3 MB/s eta 0:00:04
#    ----------------------------- ---------- 28.8/39.4 MB 3.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 29.4/39.4 MB 3.4 MB/s eta 0:00:03
#    ------------------------------ --------- 29.9/39.4 MB 3.3 MB/s eta 0:00:03
#    ------------------------------- -------- 30.9/39.4 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 32.0/39.4 MB 3.4 MB/s eta 0:00:03
#    --------------------------------- ------ 33.0/39.4 MB 3.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.1/39.4 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.1/39.4 MB 3.5 MB/s eta 0:00:02
#    ------------------------------------- -- 36.4/39.4 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 37.5/39.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.4 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 39.4/39.4 MB 3.6 MB/s  0:00:11
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn, sklearn-model
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    -------------------- ------------------- 2/4 [scikit-learn]
#    ---------------------------------------- 4/4 [sklearn-model]
#
# Successfully installed scikit-learn-1.7.2 scipy-1.16.3 sklearn-model-0.0.6 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (42434,)

# %%
X_test.shape
# Out:
# (10609,)

# %%
Y_train
# Out:
# 25559    Depression
# 34137       Anxiety
# 4750         Normal
# 34544       Anxiety
# 29290        Normal
#             ...
# 40823    Depression
# 24843    Depression
# 10509      Suicidal
# 18154    Depression
# 11786    Depression
# Name: status, Length: 42434, dtype: object

# %%
X_train
# Out:
# 25559    year dad late diagnos dementia last year dog d...
# 34137    tourett syndrom work type tick hi reddit someo...
# 4750                                            mad wonpil
# 34544    worri ive cancer progress far undiagnos apolog...
# 29290    caus quit disagr often compromis quicki later ...
#                                ...
# 40823                theekween depress anxieti thelmasherb
# 24843    feel good admit let goall ultim worthless gran...
# 10509    alway good person never anyth wrong alway nerd...
# 18154    wonder common mayb feel less depress randomli ...
# 11786    bit long stori pleas bear veteran afghanistan ...
# Name: statement, Length: 42434, dtype: object

# %% [markdown]
# #### Vecorization

# %%
def vectorizer(ds, vocabulary):
    vectorized_lst = []

    for sentence in ds:
        sentence_lst = np.zeros(len(vocabulary))

        for i in range(len(vocabulary)):
            if vocabulary[i] in sentence.split():
                sentence_lst[i] = 1

        vectorized_lst.append(sentence_lst)

    vectorized_lst_new = np.asarray(vectorized_lst, dtype = np.float32)

    return vectorized_lst_new

# %%
vectorized_x_train = vectorizer(X_train, tokens)

# %%
vectorized_x_test = vectorizer(X_test, tokens)

# %%
Y_test.value_counts()
# Out:
# status
# Normal                  3303
# Depression              3043
# Suicidal                2050
# Anxiety                  810
# Bipolar                  608
# Stress                   548
# Personality disorder     247
# Name: count, dtype: int64

# %%
Y_train.value_counts()
# Out:
# status
# Normal                  13048
# Depression              12361
# Suicidal                 8603
# Anxiety                  3078
# Bipolar                  2269
# Stress                   2121
# Personality disorder      954
# Name: count, dtype: int64

# %%
values = np.array([
    Y_train.value_counts()["Normal"],
    Y_train.value_counts()["Depression"],
    Y_train.value_counts()["Suicidal"],
    Y_train.value_counts()["Anxiety"],
    Y_train.value_counts()["Bipolar"],
    Y_train.value_counts()["Stress"],
    Y_train.value_counts()["Personality disorder"]
])

labels = [
    "Normal",
    "Depression",
    "Suicidal",
    "Anxiety",
    "Bipolar",
    "Stress",
    "Personality disorder"
]

plt.pie(values, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Distribution of Mental Health Categories")
plt.show()

# %% [markdown]
# #### Handle Imbalanced dataset

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from imbalanced-learn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\asus\documents\github\ai_project\env\lib\site-packages (from imbalanced-learn) (3.6.0)
# Downloading imbalanced_learn-0.14.0-py3-none-any.whl (239 kB)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.14.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()
vectorized_x_train_smote, y_train_smote = smote.fit_resample(vectorized_x_train, Y_train)
print(vectorized_x_train_smote.shape, y_train_smote.shape)
# Out:
# (91336, 7248) (91336,)

# %%
y_train_smote.value_counts()
# Out:
# status
# Depression              13048
# Anxiety                 13048
# Normal                  13048
# Suicidal                13048
# Stress                  13048
# Bipolar                 13048
# Personality disorder    13048
# Name: count, dtype: int64

# %%
y_train_smote
# Out:
# 0        Depression
# 1           Anxiety
# 2            Normal
# 3           Anxiety
# 4            Normal
#             ...
# 91331      Suicidal
# 91332      Suicidal
# 91333      Suicidal
# 91334      Suicidal
# 91335      Suicidal
# Name: status, Length: 91336, dtype: object

# %% [markdown]
# #### Model training and Evaluation

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

def training_scores(y_act, y_pred):
    acc = round(accuracy_score(y_act, y_pred), 3)
    pr = round(precision_score(y_act, y_pred, average='weighted'), 3)
    rec = round(recall_score(y_act, y_pred, average='weighted'), 3)
    f1 = round(f1_score(y_act, y_pred, average='weighted'), 3)
    print(f'Training Scores:\n\tAccuracy = {acc}\n\tPrecision = {pr}\n\tRecall = {rec}\n\tF1-Score = {f1}')

def validation_scores(y_act, y_pred):
    acc = round(accuracy_score(y_act, y_pred), 3)
    pr = round(precision_score(y_act, y_pred, average='weighted'), 3)
    rec = round(recall_score(y_act, y_pred, average='weighted'), 3)
    f1 = round(f1_score(y_act, y_pred, average='weighted'), 3)
    print(f'Testing Scores:\n\tAccuracy = {acc}\n\tPrecision = {pr}\n\tRecall = {rec}\n\tF1-Score = {f1}')

# %%
vectorized_x_train_smote.value_count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 x_train_smote.value_counts()
#
# NameError: name 'x_train_smote' is not defined

# %% [markdown]
# #### Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = lr.predict(vectorized_x_train_smote)

y_test_pred = lr.predict(vectorized_x_test)

training_scores(y_train_smote, y_train_pred)

validation_scores(Y_test, y_test_pred)
# Out:
# C:\Users\ASUS\Documents\GitHub\AI_Project\env\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[54], line 4
#       1 lr = LogisticRegression()
#       2 lr.fit(vectorized_x_train_smote, y_train_smote)
# ----> 4 y_train_pred = lr.predict(vectorized_x_train_smote)
#       6 y_test_pred = lr.predict(vectorized_x_test)
#       8 training_scores(y_train_smote, y_train_pred)
#
# File ~\Documents\GitHub\AI_Project\env\Lib\site-packages\sklearn\linear_model\_base.py:375, in LinearClassifierMixin.predict(self, X)
#     361 """
#     362 Predict class labels for samples in X.
#     363
#    (...)    372     Vector containing the class labels for each sample.
#     373 """
#     374 xp, _ = get_namespace(X)
# --> 375 scores = self.decision_function(X)
#     376 if len(scores.shape) == 1:
#     377     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\Documents\GitHub\AI_Project\env\Lib\site-packages\sklearn\linear_model\_base.py:353, in LinearClassifierMixin.decision_function(self, X)
#     350 xp, _ = get_namespace(X)
#     352 X = validate_data(self, X, accept_sparse="csr", reset=False)
# --> 353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# File ~\Documents\GitHub\AI_Project\env\Lib\site-packages\sklearn\utils\extmath.py:203, in safe_sparse_dot(a, b, dense_output)
#     201         ret = xp.tensordot(a, b, axes=[-1, b_axis])
#     202 else:
# --> 203     ret = a @ b
#     205 if (
#     206     sparse.issparse(a)
#     207     and sparse.issparse(b)
#     208     and dense_output
#     209     and hasattr(ret, "toarray")
#     210 ):
#     211     return ret.toarray()
#
# MemoryError: Unable to allocate 4.93 GiB for an array with shape (91336, 7248) and data type float64

# %% [markdown]
# #### Naive Bayes

# %%
mnb = MultinomialNB()
mnb.fit(vectorized_x_train_smote, y_train_smote)

y_train_pred = mnb.predict(vectorized_x_train_smote)

y_test_pred = mnb.predict(vectorized_x_test)

training_scores(y_train_smote, y_train_pred)

validation_scores(Y_test, y_test_pred)

# %% [markdown]
# #### Model File Building

# %%
import pickle

with open('../static/model/model.pickle', 'wb') as file:
    pickle.dump(lr,file)
